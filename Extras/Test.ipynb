# %%
import os

# %%
os.listdir("../output/")

for file in os.listdir("../output/"):
    print(file)
        # if "POSCAR" in file:
        #     formula_name = file.split(" ")[0]
        #     print(formula_name + " CIF generated from POSCAR content!")
# Out:
# MnNiHfW4ReB2 POSCAR
# TiNi3W3IrB2 POSCAR
# CoCuTaRe4OsB2 POSCAR
# CoFeCuMnHf2TaWB2 POSCAR
# CoMn2NiTaRe2IrB2 POSCAR
# TiFe2CuMn2HfReB2 POSCAR
# TiCoMn2HfTaRe2B2 POSCAR
# CoCuNiRe3OsIrB2 POSCAR
# CoFe2Mn3Ir2B2 POSCAR
# CuMn2Ni2HfTaWB2 POSCAR
# Ti3MnHf2WReB2 POSCAR
# Ti3Co2FeReOsB2 POSCAR
# CoFeMn2Ta3OsB2 POSCAR
# TiFeMnTaWOsIr2B2 POSCAR
# Cu2Hf4ReIrB2 POSCAR
# CoMnNi3Ta2WB2 POSCAR
# Co2FeMnNiHfRe2B2 POSCAR
# CuMnTa2OsIr3B2 POSCAR
# TiFeNiTaW4B2 POSCAR
# TiCo3CuNiRe2B2 POSCAR
# CoFe2Mn2NiHfReB2 POSCAR
# TiFe5HfReB2 POSCAR
# Mn2NiHfReOs3B2 POSCAR
# CoFeNi2TaReOsIrB2 POSCAR
# Ti2NiW3Re2B2 POSCAR
# Cu2NiHf3WReB2 POSCAR
# CuMnHf2Os2Ir2B2 POSCAR
# TiCu4Os3B2 POSCAR
# Fe2Hf2TaOs2IrB2 POSCAR
# TiCu3MnNiOsIrB2 POSCAR
# CoCu4MnNiHfB2 POSCAR
# TiFe2Cu3MnWB2 POSCAR
# CoMn2Ta2OsIr2B2 POSCAR
# TiCo2FeCu2OsIrB2 POSCAR
# TiCuNiHfW3ReB2 POSCAR
# Ti2Mn4HfOsB2 POSCAR
# FeMnNiTaWReIr2B2 POSCAR
# CoCu3MnWReOsB2 POSCAR
# Cu4TaOs3B2 POSCAR
# Ti3CoCuHfOs2B2 POSCAR
# TiFeCuHfW3ReB2 POSCAR
# ...
